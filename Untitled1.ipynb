# %%
import json
import pyperclip

# %%
f = open("channel_messages_good_enough.json", "r")
my_posts_dic_list = f.read()
f.close()
print(type(my_posts_dic_list))
my_posts_dic_str = json.loads(my_posts_dic_list)
#my_posts_dic = json.loads(my_posts_dic_str)

print(len(my_posts_dic_str))
big_str_list = [] 

for i in my_posts_dic_str:
    try:
        print(i['message'])
        big_str_list.append(i['message'])
    except:
        break

big_str = '\n\n________________________________________\n\n'.join(big_str_list[::-1])
pyperclip.copy(big_str)


# #print(my_posts_dic)
# print("The type of object is: ", type(my_posts_dic))
# stud_obj = json.loads(my_posts_dic)
# #print(stud_obj)
# print("The type of object is: ", type(stud_obj))
# json_obj = json.dumps(stud_obj)
# #print(json_obj)
# print("The type of object is: ", type(json_obj))
# Out:
# <class 'str'>
# 147
# Day 86:
# ✅❌✅❌
# #PracticalEnglish
# #MostCommonNouns
# .
# .
# * job:
# .
# .
# * Good job! (used to tell someone that they have done well at something)
# .
# .
# - I'm thinking of applying for a new job.
# - He certainly knows his job (=is very good at his job).
# - At least there’s no danger of you losing your job.
# - Levels of job satisfaction vary between departments.
# - As an actor, he has very little job security.
# - He's been out of a job (=unemployed) for six months now.
# - He had a series of dead-end jobs (=jobs with low wages and no chance of progress).
# - I'm only doing my job (=I'm doing what I am paid to do).
# - He had a part-time job at the pet shop.
# - She's never had a steady job (=a job that is not going to end suddenly).
# - Sorting these papers out is going to be a long job.
# - You've certainly done an excellent job on the kitchen (=for example, painting it).
# ...
